# %%
# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('Base.csv')

# %%
df['device_os'].sample(10)
# Out:
# 771601      other
# 408106      linux
# 153634    windows
# 660089      other
# 357070    windows
# 45208       other
# 892012      linux
# 811796      other
# 576384      linux
# 490322      other
# Name: device_os, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
#  11  velocity_24h                      1000000 non-null  float64
#  12  velocity_4w                       1000000 non-null  float64
#  13  bank_branch_count_8w              1000000 non-null  int64
#  14  date_of_birth_distinct_emails_4w  1000000 non-null  int64
#  15  employment_status                 1000000 non-null  object
#  16  credit_risk_score                 1000000 non-null  int64
#  17  email_is_free                     1000000 non-null  int64
#  18  housing_status                    1000000 non-null  object
#  19  phone_home_valid                  1000000 non-null  int64
#  20  phone_mobile_valid                1000000 non-null  int64
#  21  bank_months_count                 1000000 non-null  int64
#  22  has_other_cards                   1000000 non-null  int64
#  23  proposed_credit_limit             1000000 non-null  float64
#  24  foreign_request                   1000000 non-null  int64
#  25  source                            1000000 non-null  object
#  26  session_length_in_minutes         1000000 non-null  float64
#  27  device_os                         1000000 non-null  object
#  28  keep_alive_session                1000000 non-null  int64
#  29  device_distinct_emails_8w         1000000 non-null  int64
#  30  device_fraud_count                1000000 non-null  int64
#  31  month                             1000000 non-null  int64
# dtypes: float64(9), int64(18), object(5)
# memory usage: 244.1+ MB

# %%
sum(df['fraud_bool'])
# Out:
# 11029

# %%
df.loc[df['fraud_bool']==True,:].describe()
# Out:
#        fraud_bool        income  name_email_similarity  \
# count     11029.0  11029.000000           11029.000000
# mean          1.0      0.686635               0.393161
# std           0.0      0.265579               0.295607
# min           1.0      0.100000               0.000132
# 25%           1.0      0.600000               0.134257
# 50%           1.0      0.800000               0.292420
# 75%           1.0      0.900000               0.676543
# max           1.0      0.900000               0.999953
#
#        prev_address_months_count  current_address_months_count  customer_age  \
# count               11029.000000                  11029.000000  11029.000000
# mean                    5.861365                    114.801161     40.858645
# std                    32.816956                     85.324351     13.086334
# min                    -1.000000                     -1.000000     10.000000
# 25%                    -1.000000                     53.000000     30.000000
# 50%                    -1.000000                     94.000000     40.000000
# 75%                    -1.000000                    156.000000     50.000000
# max                   357.000000                    392.000000     90.000000
#
#        days_since_request  intended_balcon_amount  zip_count_4w   velocity_6h  \
# count        11029.000000            11029.000000  11029.000000  11029.000000
# mean             1.054615                3.962009   1622.311542   5183.913444
# std              5.707977               16.622067   1005.687071   2902.298679
# min              0.000001               -8.249792     18.000000     64.422571
# 25%              0.005911               -1.195618    909.000000   2894.349366
# 50%              0.013094               -0.900578   1328.000000   4916.464728
# 75%              0.023265               -0.562268   2050.000000   7128.603281
# max             75.495921              111.321272   6368.000000  16084.617170
#
#        ...  phone_mobile_valid  bank_months_count  has_other_cards  \
# count  ...        11029.000000       11029.000000     11029.000000
# mean   ...            0.850576          10.469580         0.084414
# std    ...            0.356522          12.875992         0.278020
# min    ...            0.000000          -1.000000         0.000000
# 25%    ...            1.000000          -1.000000         0.000000
# 50%    ...            1.000000           2.000000         0.000000
# 75%    ...            1.000000          25.000000         0.000000
# max    ...            1.000000          31.000000         1.000000
#
#        proposed_credit_limit  foreign_request  session_length_in_minutes  \
# count           11029.000000     11029.000000               11029.000000
# mean              833.986762         0.050322                   8.229520
# std               643.287556         0.218618                   9.681103
# min               190.000000         0.000000                  -1.000000
# 25%               200.000000         0.000000                   3.249171
# 50%               500.000000         0.000000                   5.121820
# 75%              1500.000000         0.000000                   8.628160
# max              2100.000000         1.000000                  77.730242
#
#        keep_alive_session  device_distinct_emails_8w  device_fraud_count  \
# count        11029.000000               11029.000000             11029.0
# mean             0.341645                   1.079427                 0.0
# std              0.474283                   0.320447                 0.0
# min              0.000000                  -1.000000                 0.0
# 25%              0.000000                   1.000000                 0.0
# 50%              0.000000                   1.000000                 0.0
# 75%              1.000000                   1.000000                 0.0
# max              1.000000                   2.000000                 0.0
#
#               month
# count  11029.000000
# mean       3.565962
# std        2.312055
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max        7.000000
#
# [8 rows x 27 columns]

# %%
# Out:
# 43        0
# 140       0
# 284       0
# 314       0
# 561       0
#          ..
# 999862    7
# 999879    7
# 999923    7
# 999938    7
# 999974    7
# Name: month, Length: 11029, dtype: int64

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10))

sns.histplot(data=df.loc[df['fraud_bool']==True,'month'],color="red",ax=axes[0],bins = 16, element = 'bars',discrete=True)
sns.histplot(data=df.loc[df['fraud_bool']==False,'month'],color="green",ax = axes[1],bins = 16, element = 'bars',discrete=True)
# Out:
# <Axes: xlabel='month', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10))

sns.kdeplot(data=df.loc[df['fraud_bool']==True,'income'],color="red",ax=axes[0])
sns.kdeplot(data=df.loc[df['fraud_bool']==False,'income'],color="green",ax=axes[1])
# Out:
# <Axes: xlabel='income', ylabel='Density'>

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10))

sns.violinplot(data=df.loc[df['fraud_bool']==True,'income'],color="red",ax=axes[0])
sns.violinplot(data=df.loc[df['fraud_bool']==False,'income'],color="green",ax=axes[1])
# Out:
# <Axes: ylabel='income'>

# %%
#Counting number of fraud vs non-fraud transactions and displaying them with their ratio
fraud = df['fraud_bool'].value_counts()[1]
notfraud = df['fraud_bool'].value_counts()[0]

print("The ratio of fraud{0} to notfraud{1} is:{2}".format(fraud,notfraud,fraud/notfraud))
# Out:
# The ratio of fraud11029 to notfraud988971 is:0.011151995356790038

# %%
# Drop the 'device_fraud_count' column not used
df = df.drop(columns=['device_fraud_count'])

# %%
plt.figure(figsize=(15, 13))
sns.heatmap(data=df.select_dtypes(include=[np.number]).corr(),cmap="seismic", annot=True,fmt=".2f", 
            cbar_kws={'label': 'Correlation'}, linewidths=0.5)
# Out:
# <Axes: >

# %%
df_blind = df.select_dtypes(include=[np.number]).drop(columns=['fraud_bool'])
label = df['fraud_bool']

# %%
from sklearn.model_selection import train_test_split
X_trainval, X_test, y_trainval, y_test = train_test_split(df_blind, label
                                                          , test_size=0.2
                                                          , stratify=df['fraud_bool']
                                                          , random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval
                                                  , test_size=0.25
                                                  , stratify=y_trainval
                                                  , random_state=42)

# %%
# Initialize the StandardScaler object and fit it to the training data
scaler = StandardScaler()
scaler.fit(X_train)

# Scale the training, validation, and test sets using the scaler
X_train_std = scaler.transform(X_train)
X_val_std = scaler.transform(X_val)
X_test_std = scaler.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler().fit(X_train)
# Out:
# StandardScaler()

# %%
from imblearn.under_sampling import RandomUnderSampler
# Undersampling will be utilized to address the issue of imbalanced classes.

# Instantiate RandomUnderSampler
rus = RandomUnderSampler(random_state=42)

# Undersample the training set
X_train_under, y_train_under = rus.fit_resample(X_train_std, y_train)

# Undersample the validation set
X_val_under, y_val_under = rus.fit_resample(X_val_std, y_val)

# %%
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
# Logistic Regression
# Run CV with 5 folds (logit)
penalty = ['l2']
C = np.logspace(0, 4, 10, 100, 1000)
print(C)
param_grid = dict(C=C, penalty=penalty)

logistic = linear_model.LogisticRegression(solver='lbfgs', max_iter=10000)
logistic_grid = GridSearchCV(logistic, param_grid, cv=5, scoring='roc_auc', verbose=10, n_jobs=-1)
logistic_grid.fit(X_train_under, y_train_under)
# Out:
# [1.00000000e+00 2.15443469e+01 4.64158883e+02 1.00000000e+04
#  2.15443469e+05 4.64158883e+06 1.00000000e+08 2.15443469e+09
#  4.64158883e+10 1.00000000e+12]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 2/5; 2/10] START C=21.544346900318832, penalty=l2...........................
# [CV 3/5; 1/10] START C=1.0, penalty=l2..........................................
# [CV 4/5; 1/10] START C=1.0, penalty=l2..........................................
# [CV 3/5; 2/10] START C=21.544346900318832, penalty=l2...........................
# [CV 2/5; 1/10] START C=1.0, penalty=l2..........................................
# [CV 1/5; 2/10] START C=21.544346900318832, penalty=l2...........................
# [CV 5/5; 1/10] START C=1.0, penalty=l2..........................................
# [CV 1/5; 1/10] START C=1.0, penalty=l2..........................................
# [CV 1/5; 2/10] END C=21.544346900318832, penalty=l2;, score=0.828 total time=   0.1s
# [CV 2/5; 1/10] END ...........C=1.0, penalty=l2;, score=0.848 total time=   0.1s
# [CV 4/5; 1/10] END ...........C=1.0, penalty=l2;, score=0.833 total time=   0.1s
# [CV 3/5; 2/10] END C=21.544346900318832, penalty=l2;, score=0.845 total time=   0.1s
# [CV 3/5; 1/10] END ...........C=1.0, penalty=l2;, score=0.845 total time=   0.1s
# [CV 5/5; 1/10] END ...........C=1.0, penalty=l2;, score=0.839 total time=   0.1s
# [CV 1/5; 1/10] END ...........C=1.0, penalty=l2;, score=0.828 total time=   0.1s
# [CV 2/5; 2/10] END C=21.544346900318832, penalty=l2;, score=0.848 total time=   0.1s
# [CV 4/5; 2/10] START C=21.544346900318832, penalty=l2...........................
# [CV 5/5; 2/10] START C=21.544346900318832, penalty=l2...........................
# [CV 1/5; 3/10] START C=464.15888336127773, penalty=l2...........................
# [CV 2/5; 3/10] START C=464.15888336127773, penalty=l2...........................
# [CV 3/5; 3/10] START C=464.15888336127773, penalty=l2...........................
# [CV 4/5; 3/10] START C=464.15888336127773, penalty=l2...........................
# [CV 5/5; 3/10] START C=464.15888336127773, penalty=l2...........................
# [CV 1/5; 4/10] START C=9999.999999999995, penalty=l2............................
# [CV 4/5; 2/10] END C=21.544346900318832, penalty=l2;, score=0.833 total time=   0.0s
# [CV 2/5; 4/10] START C=9999.999999999995, penalty=l2............................
# [CV 1/5; 3/10] END C=464.15888336127773, penalty=l2;, score=0.828 total time=   0.0s
# [CV 3/5; 4/10] START C=9999.999999999995, penalty=l2............................
# [CV 2/5; 3/10] END C=464.15888336127773, penalty=l2;, score=0.848 total time=   0.0s
# [CV 4/5; 4/10] START C=9999.999999999995, penalty=l2............................
# [CV 1/5; 4/10] END C=9999.999999999995, penalty=l2;, score=0.828 total time=   0.0s
# [CV 5/5; 4/10] START C=9999.999999999995, penalty=l2............................
# [CV 5/5; 2/10] END C=21.544346900318832, penalty=l2;, score=0.839 total time=   0.1s
# [CV 3/5; 3/10] END C=464.15888336127773, penalty=l2;, score=0.845 total time=   0.1s
# [CV 4/5; 3/10] END C=464.15888336127773, penalty=l2;, score=0.833 total time=   0.1s
# [CV 1/5; 5/10] START C=215443.46900318822, penalty=l2...........................
# [CV 5/5; 3/10] END C=464.15888336127773, penalty=l2;, score=0.839 total time=   0.1s
# [CV 2/5; 5/10] START C=215443.46900318822, penalty=l2...........................
# [CV 3/5; 5/10] START C=215443.46900318822, penalty=l2...........................
# [CV 3/5; 4/10] END C=9999.999999999995, penalty=l2;, score=0.845 total time=   0.0s
# [CV 4/5; 5/10] START C=215443.46900318822, penalty=l2...........................
# [CV 5/5; 5/10] START C=215443.46900318822, penalty=l2...........................
# [CV 2/5; 4/10] END C=9999.999999999995, penalty=l2;, score=0.848 total time=   0.1s
# [CV 1/5; 6/10] START C=4641588.833612782, penalty=l2............................
# [CV 5/5; 4/10] END C=9999.999999999995, penalty=l2;, score=0.839 total time=   0.0s
# [CV 2/5; 6/10] START C=4641588.833612782, penalty=l2............................
# [CV 1/5; 5/10] END C=215443.46900318822, penalty=l2;, score=0.828 total time=   0.0s
# [CV 4/5; 4/10] END C=9999.999999999995, penalty=l2;, score=0.833 total time=   0.1s
# [CV 3/5; 6/10] START C=4641588.833612782, penalty=l2............................
# [CV 2/5; 5/10] END C=215443.46900318822, penalty=l2;, score=0.848 total time=   0.0s
# [CV 3/5; 5/10] END C=215443.46900318822, penalty=l2;, score=0.845 total time=   0.0s
# [CV 4/5; 6/10] START C=4641588.833612782, penalty=l2............................
# [CV 5/5; 6/10] START C=4641588.833612782, penalty=l2............................
# [CV 1/5; 7/10] START C=99999999.9999999, penalty=l2.............................
# [CV 5/5; 5/10] END C=215443.46900318822, penalty=l2;, score=0.839 total time=   0.0s
# [CV 2/5; 7/10] START C=99999999.9999999, penalty=l2.............................
# [CV 4/5; 5/10] END C=215443.46900318822, penalty=l2;, score=0.833 total time=   0.1s
# [CV 3/5; 7/10] START C=99999999.9999999, penalty=l2.............................
# [CV 1/5; 6/10] END C=4641588.833612782, penalty=l2;, score=0.828 total time=   0.1s
# [CV 4/5; 6/10] END C=4641588.833612782, penalty=l2;, score=0.833 total time=   0.1s
# [CV 3/5; 7/10] END C=99999999.9999999, penalty=l2;, score=0.845 total time=   0.0s
# [CV 3/5; 6/10] END C=4641588.833612782, penalty=l2;, score=0.845 total time=   0.1s
# [CV 4/5; 7/10] START C=99999999.9999999, penalty=l2.............................
# [CV 5/5; 7/10] START C=99999999.9999999, penalty=l2.............................
# [CV 1/5; 8/10] START C=2154434690.031878, penalty=l2............................
# [CV 2/5; 8/10] START C=2154434690.031878, penalty=l2............................
# [CV 5/5; 6/10] END C=4641588.833612782, penalty=l2;, score=0.839 total time=   0.1s
# [CV 1/5; 7/10] END C=99999999.9999999, penalty=l2;, score=0.828 total time=   0.1s
# [CV 2/5; 6/10] END C=4641588.833612782, penalty=l2;, score=0.848 total time=   0.1s
# [CV 3/5; 8/10] START C=2154434690.031878, penalty=l2............................
# [CV 4/5; 8/10] START C=2154434690.031878, penalty=l2............................
# [CV 5/5; 8/10] START C=2154434690.031878, penalty=l2............................
# [CV 2/5; 7/10] END C=99999999.9999999, penalty=l2;, score=0.848 total time=   0.1s
# [CV 4/5; 7/10] END C=99999999.9999999, penalty=l2;, score=0.833 total time=   0.0s
# [CV 1/5; 9/10] START C=46415888336.12772, penalty=l2............................
# [CV 2/5; 9/10] START C=46415888336.12772, penalty=l2............................
# [CV 1/5; 8/10] END C=2154434690.031878, penalty=l2;, score=0.828 total time=   0.0s
# [CV 3/5; 9/10] START C=46415888336.12772, penalty=l2............................
# [CV 5/5; 7/10] END C=99999999.9999999, penalty=l2;, score=0.839 total time=   0.1s
# [CV 2/5; 8/10] END C=2154434690.031878, penalty=l2;, score=0.848 total time=   0.1s
# [CV 4/5; 9/10] START C=46415888336.12772, penalty=l2............................
# [CV 5/5; 9/10] START C=46415888336.12772, penalty=l2............................
# [CV 4/5; 8/10] END C=2154434690.031878, penalty=l2;, score=0.833 total time=   0.0s
# [CV 3/5; 8/10] END C=2154434690.031878, penalty=l2;, score=0.845 total time=   0.0s
# [CV 1/5; 10/10] START C=1000000000000.0, penalty=l2.............................
# [CV 5/5; 8/10] END C=2154434690.031878, penalty=l2;, score=0.839 total time=   0.0s
# [CV 2/5; 10/10] START C=1000000000000.0, penalty=l2.............................
# [CV 3/5; 10/10] START C=1000000000000.0, penalty=l2.............................
# [CV 1/5; 9/10] END C=46415888336.12772, penalty=l2;, score=0.828 total time=   0.0s
# [CV 4/5; 10/10] START C=1000000000000.0, penalty=l2.............................
# [CV 3/5; 9/10] END C=46415888336.12772, penalty=l2;, score=0.845 total time=   0.0s
# [CV 5/5; 10/10] START C=1000000000000.0, penalty=l2.............................
# [CV 2/5; 9/10] END C=46415888336.12772, penalty=l2;, score=0.848 total time=   0.0s
# [CV 4/5; 9/10] END C=46415888336.12772, penalty=l2;, score=0.833 total time=   0.0s
# [CV 1/5; 10/10] END C=1000000000000.0, penalty=l2;, score=0.828 total time=   0.0s
# [CV 5/5; 9/10] END C=46415888336.12772, penalty=l2;, score=0.839 total time=   0.0s
# [CV 2/5; 10/10] END C=1000000000000.0, penalty=l2;, score=0.848 total time=   0.0s
# [CV 3/5; 10/10] END C=1000000000000.0, penalty=l2;, score=0.845 total time=   0.0s
# [CV 4/5; 10/10] END C=1000000000000.0, penalty=l2;, score=0.833 total time=   0.0s
# [CV 5/5; 10/10] END C=1000000000000.0, penalty=l2;, score=0.839 total time=   0.0s
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=10000), n_jobs=-1,
#              param_grid={'C': array([1.00000000e+00, 2.15443469e+01, 4.64158883e+02, 1.00000000e+04,
#        2.15443469e+05, 4.64158883e+06, 1.00000000e+08, 2.15443469e+09,
#        4.64158883e+10, 1.00000000e+12]),
#                          'penalty': ['l2']},
#              scoring='roc_auc', verbose=10)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb_best = gnb.fit(X_train_under, y_train_under)

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'max_depth': [5, 10, 15],
    'max_features': ['sqrt'],
    'min_samples_leaf': [10, 20],
    'min_samples_split': [2, 5],
    'n_estimators': [500, 700]
}

rf = RandomForestClassifier()
rf_grid = GridSearchCV(rf, param_grid, cv=5, scoring='roc_auc', verbose=10, n_jobs=-1)
rf_grid.fit(X_train_under,y_train_under)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 2/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 2/5; 2/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 2/5; 1/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 5/5; 1/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 3/5; 2/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 3/5; 1/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 1/5; 1/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 4/5; 1/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 1/5; 1/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.842 total time=  10.1s
# [CV 4/5; 2/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 3/5; 1/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.842 total time=  10.1s
# [CV 5/5; 2/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 4/5; 1/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.840 total time=  10.1s
# [CV 1/5; 3/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 2/5; 1/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.847 total time=  10.1s
# [CV 2/5; 3/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 5/5; 1/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.846 total time=  10.2s
# [CV 3/5; 3/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 3/5; 2/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.842 total time=  14.6s
# [CV 2/5; 2/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.845 total time=  14.6s
# [CV 4/5; 3/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 5/5; 3/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 1/5; 2/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.843 total time=  14.7s
# [CV 1/5; 4/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 2/5; 3/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.847 total time=  12.1s
# [CV 1/5; 3/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.843 total time=  12.1s
# [CV 2/5; 4/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 3/5; 4/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 3/5; 3/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.842 total time=  12.2s
# [CV 4/5; 4/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 5/5; 3/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.846 total time=  12.6s
# [CV 4/5; 2/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.840 total time=  17.2s
# [CV 5/5; 4/24] START max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 1/5; 5/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 4/5; 3/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.841 total time=  12.7s
# [CV 2/5; 5/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 5/5; 2/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.846 total time=  17.5s
# [CV 3/5; 5/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 1/5; 4/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.843 total time=  17.1s
# [CV 4/5; 5/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 1/5; 5/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.843 total time=  11.4s
# [CV 5/5; 5/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 2/5; 5/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.845 total time=  11.9s
# [CV 1/5; 6/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 2/5; 4/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.846 total time=  17.6s
# [CV 2/5; 6/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 3/5; 5/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.842 total time=  12.4s
# [CV 3/5; 6/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 3/5; 4/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.841 total time=  17.7s
# [CV 4/5; 6/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 4/5; 4/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.840 total time=  17.7s
# [CV 5/5; 6/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 5/5; 4/24] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.846 total time=  18.9s
# [CV 1/5; 7/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 4/5; 5/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.840 total time=  14.5s
# [CV 2/5; 7/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 5/5; 5/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.846 total time=  16.2s
# [CV 3/5; 7/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 3/5; 6/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.842 total time=  19.5s
# [CV 4/5; 7/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 1/5; 7/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.843 total time=  13.3s
# [CV 5/5; 7/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 2/5; 6/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.846 total time=  19.8s
# [CV 1/5; 8/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 4/5; 6/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.840 total time=  19.7s
# [CV 2/5; 8/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 1/5; 6/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.842 total time=  20.5s
# [CV 3/5; 8/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 2/5; 7/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.846 total time=  13.4s
# [CV 4/5; 8/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 5/5; 6/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.846 total time=  20.0s
# [CV 5/5; 8/24] START max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 3/5; 7/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.842 total time=  10.3s
# [CV 1/5; 9/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 4/5; 7/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.839 total time=  10.0s
# [CV 2/5; 9/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 5/5; 7/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.845 total time=  10.0s
# [CV 3/5; 9/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 3/5; 8/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.842 total time=  14.0s
# [CV 4/5; 8/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.840 total time=  14.0s
# [CV 4/5; 9/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 5/5; 9/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 1/5; 8/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.842 total time=  14.3s
# [CV 1/5; 10/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 2/5; 8/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.847 total time=  14.2s
# [CV 2/5; 10/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 5/5; 8/24] END max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.846 total time=  14.3s
# [CV 3/5; 10/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 1/5; 9/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.856 total time=  17.0s
# [CV 4/5; 10/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 3/5; 9/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.856 total time=  17.0s
# [CV 5/5; 10/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 2/5; 9/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.865 total time=  17.1s
# [CV 1/5; 11/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 4/5; 9/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.853 total time=  17.1s
# [CV 2/5; 11/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 5/5; 9/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.860 total time=  17.2s
# [CV 3/5; 11/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 1/5; 10/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.856 total time=  24.4s
# [CV 4/5; 11/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 2/5; 10/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.866 total time=  25.2s
# [CV 5/5; 11/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 3/5; 10/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.857 total time=  25.4s
# [CV 1/5; 12/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 1/5; 11/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.856 total time=  19.3s
# [CV 2/5; 12/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 4/5; 10/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.853 total time=  26.4s
# [CV 3/5; 12/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 3/5; 11/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.856 total time=  20.0s
# [CV 4/5; 12/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 2/5; 11/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.865 total time=  20.1s
# [CV 5/5; 12/24] START max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 5/5; 10/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.859 total time=  26.7s
# [CV 1/5; 13/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 4/5; 11/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.853 total time=  19.3s
# [CV 2/5; 13/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 5/5; 11/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.859 total time=  18.8s
# [CV 3/5; 13/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 1/5; 12/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.857 total time=  25.3s
# [CV 4/5; 13/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 1/5; 13/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.854 total time=  15.6s
# [CV 5/5; 13/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 2/5; 12/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.866 total time=  24.3s
# [CV 1/5; 14/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 3/5; 12/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.857 total time=  23.5s
# [CV 2/5; 14/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 2/5; 13/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.864 total time=  15.2s
# [CV 3/5; 14/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 3/5; 13/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.854 total time=  15.1s
# [CV 4/5; 14/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 5/5; 12/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.859 total time=  23.2s
# [CV 5/5; 14/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 4/5; 12/24] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.852 total time=  23.4s
# [CV 1/5; 15/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 4/5; 13/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.851 total time=  14.9s
# [CV 2/5; 15/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 5/5; 13/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.857 total time=  15.1s
# [CV 3/5; 15/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 1/5; 15/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.854 total time=  15.3s
# [CV 4/5; 15/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 1/5; 14/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.854 total time=  21.3s
# [CV 5/5; 15/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 2/5; 14/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.864 total time=  21.2s
# [CV 1/5; 16/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 3/5; 14/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.855 total time=  21.2s
# [CV 2/5; 16/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 4/5; 14/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.851 total time=  21.2s
# [CV 3/5; 16/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 2/5; 15/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.864 total time=  15.3s
# [CV 4/5; 16/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 5/5; 14/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.857 total time=  21.0s
# [CV 5/5; 16/24] START max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 3/5; 15/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.856 total time=  15.2s
# [CV 1/5; 17/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 4/5; 15/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.851 total time=  15.2s
# [CV 2/5; 17/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 5/5; 15/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.858 total time=  15.0s
# [CV 3/5; 17/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 1/5; 16/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.855 total time=  21.1s
# [CV 4/5; 17/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 2/5; 16/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.864 total time=  21.2s
# [CV 5/5; 17/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500
# [CV 3/5; 16/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.855 total time=  21.0s
# [CV 1/5; 18/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 4/5; 16/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.851 total time=  21.1s
# [CV 2/5; 18/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 5/5; 16/24] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.858 total time=  21.1s
# [CV 3/5; 18/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 1/5; 17/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.858 total time=  17.8s
# [CV 4/5; 18/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 2/5; 17/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.866 total time=  18.0s
# [CV 5/5; 18/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700
# [CV 3/5; 17/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.857 total time=  18.1s
# [CV 1/5; 19/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 4/5; 17/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.854 total time=  18.5s
# [CV 2/5; 19/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 5/5; 17/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500;, score=0.860 total time=  18.5s
# [CV 3/5; 19/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 1/5; 18/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.858 total time=  25.6s
# [CV 4/5; 19/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 2/5; 18/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.867 total time=  25.5s
# [CV 5/5; 19/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500
# [CV 3/5; 18/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.857 total time=  25.6s
# [CV 1/5; 20/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 4/5; 18/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.855 total time=  25.7s
# [CV 2/5; 20/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 1/5; 19/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.858 total time=  18.6s
# [CV 3/5; 20/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 5/5; 18/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=700;, score=0.860 total time=  25.5s
# [CV 4/5; 20/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 2/5; 19/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.866 total time=  17.7s
# [CV 5/5; 20/24] START max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700
# [CV 3/5; 19/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.857 total time=  17.5s
# [CV 1/5; 21/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 4/5; 19/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.854 total time=  17.5s
# [CV 2/5; 21/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 5/5; 19/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=500;, score=0.860 total time=  17.5s
# [CV 3/5; 21/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 1/5; 20/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.858 total time=  24.5s
# [CV 4/5; 21/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 2/5; 20/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.867 total time=  24.4s
# [CV 5/5; 21/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500
# [CV 1/5; 21/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.856 total time=  15.6s
# [CV 1/5; 22/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 3/5; 20/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.857 total time=  24.5s
# [CV 2/5; 22/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 4/5; 20/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.855 total time=  24.4s
# [CV 3/5; 22/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 2/5; 21/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.864 total time=  15.6s
# [CV 4/5; 22/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 3/5; 21/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.855 total time=  15.7s
# [CV 5/5; 22/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700
# [CV 5/5; 20/24] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700;, score=0.860 total time=  24.6s
# [CV 1/5; 23/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 4/5; 21/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.852 total time=  16.1s
# [CV 2/5; 23/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 5/5; 21/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500;, score=0.857 total time=  16.0s
# [CV 3/5; 23/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 1/5; 22/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.855 total time=  22.3s
# [CV 4/5; 23/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 2/5; 22/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.865 total time=  22.4s
# [CV 5/5; 23/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500
# [CV 1/5; 23/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.855 total time=  16.2s
# [CV 1/5; 24/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 3/5; 22/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.855 total time=  22.6s
# [CV 2/5; 24/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 4/5; 22/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.852 total time=  22.9s
# [CV 3/5; 24/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 5/5; 22/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=700;, score=0.858 total time=  22.8s
# [CV 4/5; 24/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 2/5; 23/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.865 total time=  16.7s
# [CV 5/5; 24/24] START max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700
# [CV 3/5; 23/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.855 total time=  16.9s
# [CV 4/5; 23/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.853 total time=  17.3s
# [CV 5/5; 23/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500;, score=0.858 total time=  17.1s
# [CV 1/5; 24/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.855 total time=  22.5s
# [CV 2/5; 24/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.865 total time=  22.1s
# [CV 3/5; 24/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.855 total time=  21.4s
# [CV 4/5; 24/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.852 total time=  21.2s
# [CV 5/5; 24/24] END max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=700;, score=0.857 total time=  20.3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [500, 700]},
#              scoring='roc_auc', verbose=10)

# %%
from sklearn.dummy import DummyClassifier
# Dummy Classifier
dummy = DummyClassifier()
dummy.fit(X_train_under, y_train_under)
# Out:
# DummyClassifier()

# %%
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, precision_recall_curve, f1_score, fbeta_score, accuracy_score

def plot_roc_curves(X, y, models, model_names, figsize=(20,18)):
    """
    Plots ROC curves for a list of models.

    Parameters:
    X (numpy.ndarray or pandas.DataFrame): input features for the models
    y (numpy.ndarray or pandas.DataFrame): target variable
    models (list): list of models to compare
    model_names (list): list of model names to display on the plot
    figsize (tuple): size of the figure to display the plot

    Returns:
    None
    """
    fig, ax = plt.subplots(figsize=figsize)

    # Loop over models and plot ROC curve
    for i, model in enumerate(models):
        y_pred = list(model.predict_proba(X)[:, 1])
        fpr, tpr, threshold = metrics.roc_curve(y, y_pred)
        roc_auc = metrics.auc(fpr, tpr)
        plt.plot(fpr, tpr, label=(model_names[i] + ' AUC = %0.4f' % roc_auc), linewidth=2.0)

    ax.grid(False)
    ax.tick_params(length=6, width=2, labelsize=30, grid_color='r', grid_alpha=0.5)
    leg = plt.legend(loc='lower right', prop={'size': 25})
    leg.get_frame().set_edgecolor('b')
    plt.title('Receiver Operating Characteristic (ROC)', fontsize=40)
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([-.02, 1.02])
    plt.ylim([-.02, 1.02])
    plt.ylabel('True Positive Rate', fontsize=30)
    plt.xlabel('False Positive Rate', fontsize=30)
#     plt.show()

# %%
# Define the list of models to compare
models = [logistic_grid.best_estimator_, gnb_best, rf_grid.best_estimator_, dummy]
model_names = ['Logit', 'Naive Bayes', 'Random Forest', 'Dummy']

# %%
# Plot ROC curves for in-sample data
plot_roc_curves(X_val_under, y_val_under, models, model_names)

# Save the plot as PNG file
plt.savefig('roc_insample.png');

# %%
# Plot ROC curves for out-of-sample data
plot_roc_curves(X_test_std, y_test, models, model_names)

# Save the plot as PNG file
plt.savefig('roc_outsample.png');
